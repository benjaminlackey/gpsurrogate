# %%
import numpy as np
from scipy import stats
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import glob, os

# %%
def Lambda_tilde(m1, m2, lambda1, lambda2):
    return 16.0/13.0 * ((m1 + 12*m2)*m1**4*lambda1 + (m2 + 12*m1)*m2**4*lambda2) / (m1 + m2)**5

# %% [markdown]
# ## f_min=20Hz grid

# %%
# m1, m2, chi1, chi2, lambda1, lambda2, match
matches20 = np.loadtxt('matches_f_min_20.000000_f_max_8192.000000_df_0.007812.dat')
m1, m2, chi1, chi2, lambda1, lambda2, match = matches20.T
chi_eff = (m1*chi1 + m2*chi2) / (m1+m2)
Ltilde = Lambda_tilde(m1, m2, lambda1, lambda2)

# %%
plt.hist(match);

# %%
plt.scatter(m1 / m2, chi_eff, c=match)
plt.xlabel(r'$q$')
plt.ylabel(r'$\chi_\mathrm{eff}$')
plt.colorbar();

# %%
plt.scatter(m1 / m2, Ltilde, c=match)
plt.xlabel(r'$q$')
plt.ylabel(r'$\tilde\Lambda$')
plt.colorbar();
