# %% [markdown]
# ```
# Join multiple WaveformSet objects to form a larger training set.
# ```

# %%
# %pylab inline
#%matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

import matplotlib
matplotlib.__version__
# Out:
# Populating the interactive namespace from numpy and matplotlib
# '2.2.2'

# %%
sys.path.insert(0, '../../src')

import waveform as wave
import waveformset as ws

import imp
imp.reload(wave)
imp.reload(ws)
# Out:
# <module 'waveformset' from '../../src/waveformset.py'>

# %%
type(range(400))
# Out:
# list

# %% [markdown]
# # Matern 5/2 kernel

# %% [markdown]
# ## Combine LHD and 400 uniform (sampled in xi)

# %%
filename1 = '../../data/TEOBv4QM_production/h_train_corners_lhd_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/h_train_uniformxi.hdf5'
filename_join = '../../data/TEOBv4QM_production/h_train_lhd_uniform_xi.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

filename1 = '../../data/TEOBv4QM_production/dh_train_corners_lhd_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/dh_train_uniformxi.hdf5'
filename_join = '../../data/TEOBv4QM_production/dh_train_lhd_uniform_xi.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

# %%
h_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/h_train_lhd_uniform_xi.hdf5')
dh_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/dh_train_lhd_uniform_xi.hdf5')

# %%
fig, (ax1, ax2) = wave.plot_waveforms_fd([h_train[i] for i in range(len(h_train))])
ax1.set_yscale('log')
ax1.set_ylabel(r'$A$')
ax2.set_ylabel(r'$\Phi$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

fig, (ax1, ax2) = wave.plot_waveforms_fd([dh_train[i] for i in range(len(dh_train))])
ax1.set_ylabel(r'$\ln(A/A_{\rm F2})$')
ax2.set_ylabel(r'$\Phi-\Phi_{\rm F2}$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

# %% [markdown]
# ## Combine LHD and uncertainty sampling training sets (sampled in xi)

# %%
filename1 = '../../data/TEOBv4QM_production/h_train_corners_lhd_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/h_train_uncsamp_xi.hdf5'
filename_join = '../../data/TEOBv4QM_production/h_train_lhd_uncsamp_xi.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

filename1 = '../../data/TEOBv4QM_production/dh_train_corners_lhd_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/dh_train_uncsamp_xi.hdf5'
filename_join = '../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_xi.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

# %%
h_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/h_train_lhd_uncsamp_xi.hdf5')
dh_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_xi.hdf5')

# %%
fig, (ax1, ax2) = wave.plot_waveforms_fd([h_train[i] for i in range(len(h_train))])
ax1.set_yscale('log')
ax1.set_ylabel(r'$A$')
ax2.set_ylabel(r'$\Phi$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

fig, (ax1, ax2) = wave.plot_waveforms_fd([dh_train[i] for i in range(len(dh_train))])
ax1.set_ylabel(r'$\ln(A/A_{\rm F2})$')
ax2.set_ylabel(r'$\Phi-\Phi_{\rm F2}$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

# %% [markdown]
# ## Combine 160 LHD + 400 uncertainty sampling + 400 random samples (sampled in xi)

# %%
filename1 = '../../data/TEOBv4QM_production/h_train_lhd_uncsamp_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/h_train_uniformxi.hdf5'
filename_join = '../../data/TEOBv4QM_production/h_train_lhd_uncsamp_uniform_xi.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

filename1 = '../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/dh_train_uniformxi.hdf5'
filename_join = '../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_uniform_xi.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

# %%
h_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/h_train_lhd_uncsamp_uniform_xi.hdf5')
dh_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_uniform_xi.hdf5')

# %%
fig, (ax1, ax2) = wave.plot_waveforms_fd([h_train[i] for i in range(len(h_train))])
ax1.set_yscale('log')
ax1.set_ylabel(r'$A$')
ax2.set_ylabel(r'$\Phi$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

fig, (ax1, ax2) = wave.plot_waveforms_fd([dh_train[i] for i in range(len(dh_train))])
ax1.set_ylabel(r'$\ln(A/A_{\rm F2})$')
ax2.set_ylabel(r'$\Phi-\Phi_{\rm F2}$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

# %% [markdown]
# # Squared exponential kernel

# %% [markdown]
# ## Combine LHD and 400 uncertainty sampling (sq. exp.) training sets (sampled in xi)

# %%
filename1 = '../../data/TEOBv4QM_production/h_train_corners_lhd_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/h_train_uncsamp_xi_sqexp.hdf5'
filename_join = '../../data/TEOBv4QM_production/h_train_lhd_uncsamp_xi_sqexp.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

filename1 = '../../data/TEOBv4QM_production/dh_train_corners_lhd_xi.hdf5'
filename2 = '../../data/TEOBv4QM_production/dh_train_uncsamp_xi_sqexp.hdf5'
filename_join = '../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_xi_sqexp.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

# %%
h_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/h_train_lhd_uncsamp_xi_sqexp.hdf5')
dh_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_xi_sqexp.hdf5')

# %%
fig, (ax1, ax2) = wave.plot_waveforms_fd([h_train[i] for i in range(len(h_train))])
ax1.set_yscale('log')
ax1.set_ylabel(r'$A$')
ax2.set_ylabel(r'$\Phi$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

fig, (ax1, ax2) = wave.plot_waveforms_fd([dh_train[i] for i in range(len(dh_train))])
ax1.set_ylabel(r'$\ln(A/A_{\rm F2})$')
ax2.set_ylabel(r'$\Phi-\Phi_{\rm F2}$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

# %% [markdown]
# ## Combine 160 LHD + 400 uncertainty sampling + 400 random samples (sq. exp.) (sampled in xi)

# %%
filename1 = '../../data/TEOBv4QM_production/h_train_lhd_uncsamp_xi_sqexp.hdf5'
filename2 = '../../data/TEOBv4QM_production/h_train_uniformxi.hdf5'
filename_join = '../../data/TEOBv4QM_production/h_train_lhd_uncsamp_uniform_xi_sqexp.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

filename1 = '../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_xi_sqexp.hdf5'
filename2 = '../../data/TEOBv4QM_production/dh_train_uniformxi.hdf5'
filename_join = '../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_uniform_xi_sqexp.hdf5'
list2 = list(range(400))
ws.join_waveform_sets(filename1, filename2, filename_join, list2=list2)

# %%
h_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/h_train_lhd_uncsamp_uniform_xi_sqexp.hdf5')
dh_train = ws.HDF5WaveformSet('../../data/TEOBv4QM_production/dh_train_lhd_uncsamp_uniform_xi_sqexp.hdf5')

# %%
fig, (ax1, ax2) = wave.plot_waveforms_fd([h_train[i] for i in range(len(h_train))])
ax1.set_yscale('log')
ax1.set_ylabel(r'$A$')
ax2.set_ylabel(r'$\Phi$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()

fig, (ax1, ax2) = wave.plot_waveforms_fd([dh_train[i] for i in range(len(dh_train))])
ax1.set_ylabel(r'$\ln(A/A_{\rm F2})$')
ax2.set_ylabel(r'$\Phi-\Phi_{\rm F2}$')
ax2.set_xlabel(r'$Mf$')
ax1.grid()
ax2.grid()
